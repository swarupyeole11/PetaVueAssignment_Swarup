# %%
from google.colab import drive

# Mount Google Drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from google.colab import drive
import zipfile
import os
import pandas as pd

# Step 1: Mount Google Drive


# Step 2: Access the zip file and extract its contents
zip_path = '/content/drive/MyDrive/Flight Data/2016_original.zip'
extracted_path = '/content/extracted_files'

with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    print(zip_path)
    zip_ref.extractall(extracted_path)
    print(extracted_path)

# Step 3: Merge the CSV files into a single DataFrame
# Out:
# /content/drive/MyDrive/Flight Data/2016_original.zip
# /content/extracted_files

# %%
merged_df = pd.DataFrame()

for root, dirs, files in os.walk(os.path.join(extracted_path, '2016')):
    for file_name in files:
        if file_name.endswith('.csv'):
            file_path = os.path.join(root, file_name)
            df = pd.read_csv(file_path)
            merged_df = pd.concat([merged_df, df], ignore_index=True)

# Step 4: Save the merged DataFrame to a new CSV file
merged_df.to_csv('/content/merged_file2016.csv', index=False)
# Out:
# <ipython-input-7-732d4d929988>:7: DtypeWarning: Columns (48,77,84,85) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# <ipython-input-7-732d4d929988>:7: DtypeWarning: Columns (48,77,84) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# <ipython-input-7-732d4d929988>:7: DtypeWarning: Columns (48,77,84) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# <ipython-input-7-732d4d929988>:7: DtypeWarning: Columns (48,77,84) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# <ipython-input-7-732d4d929988>:7: DtypeWarning: Columns (48,77,84) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# <ipython-input-7-732d4d929988>:7: DtypeWarning: Columns (48,69,76,77,84) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# <ipython-input-7-732d4d929988>:7: DtypeWarning: Columns (77,84) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# <ipython-input-7-732d4d929988>:7: DtypeWarning: Columns (48,77,84) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# <ipython-input-7-732d4d929988>:7: DtypeWarning: Columns (77) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# <ipython-input-7-732d4d929988>:7: DtypeWarning: Columns (48,77,84) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# <ipython-input-7-732d4d929988>:7: DtypeWarning: Columns (48,77,84) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# <ipython-input-7-732d4d929988>:7: DtypeWarning: Columns (48,77,84) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)

# %%
import os
import pandas as pd

merged_df = pd.DataFrame()
extracted_path = '/content/extracted_files'

columns_to_keep = ['FlightDate', 'Quarter', 'Year', 'Month', 'DayofMonth', 'DepTime', 'DepDel15',
                   'CRSDepTime', 'DepDelayMinutes', 'Origin', 'Dest', 'ArrTime', 'CRSArrTime',
                   'ArrDel15', 'ArrDelayMinutes']

flight_codes = ['ATL', 'CLT', 'DEN', 'DFW', 'EWR', 'IAH', 'JFK', 'LAS', 'LAX', 'MCO', 'MIA', 'ORD', 'PHX', 'SEA', 'SFO']

for root, dirs, files in os.walk(os.path.join(extracted_path, '2016')):
    for file_name in files:
        if file_name.endswith('.csv'):
            file_path = os.path.join(root, file_name)
            df = pd.read_csv(file_path, usecols=columns_to_keep)

            filtered_df = df[df['Origin'].isin(flight_codes) & df['Dest'].isin(flight_codes)]
            merged_df = pd.concat([merged_df, filtered_df], ignore_index=True)

# Step 4: Save the merged DataFrame to a new CSV file
merged_df.to_csv('/content/merged_file2016_trimmed_final.csv', index=False)

# %%
import pandas as pd
df = pd.read_csv("/content/merged_file2016_trimmed_final.csv")
df
# Out:
#         Year  Quarter  Month  DayofMonth  FlightDate Origin Dest  CRSDepTime  \
# 0       2016        2      5           1  2016-05-01    JFK  LAX         900
# 1       2016        2      5           2  2016-05-02    JFK  LAX         900
# 2       2016        2      5           3  2016-05-03    JFK  LAX         900
# 3       2016        2      5           4  2016-05-04    JFK  LAX         900
# 4       2016        2      5           5  2016-05-05    JFK  LAX         900
# ...      ...      ...    ...         ...         ...    ...  ...         ...
# 948814  2016        4     12          30  2016-12-30    PHX  SEA         810
# 948815  2016        4     12          30  2016-12-30    PHX  JFK         630
# 948816  2016        4     12          30  2016-12-30    SEA  JFK        2259
# 948817  2016        4     12          30  2016-12-30    ATL  LAS         942
# 948818  2016        4     12          30  2016-12-30    MCO  ATL         830
#
#         DepTime  DepDelayMinutes  DepDel15  CRSArrTime  ArrTime  \
# 0         931.0             31.0       1.0        1217   1226.0
# 1         853.0              0.0       0.0        1217   1216.0
# 2         857.0              0.0       0.0        1217   1226.0
# 3         854.0              0.0       0.0        1217   1157.0
# 4         857.0              0.0       0.0        1217   1214.0
# ...         ...              ...       ...         ...      ...
# 948814    803.0              0.0       0.0        1028   1006.0
# 948815    624.0              0.0       0.0        1312   1246.0
# 948816   2256.0              0.0       0.0         720    705.0
# 948817    936.0              0.0       0.0        1115   1149.0
# 948818    846.0             16.0       1.0        1009   1014.0
#
#         ArrDelayMinutes  ArrDel15
# 0                   9.0       0.0
# 1                   0.0       0.0
# 2                   9.0       0.0
# 3                   0.0       0.0
# 4                   0.0       0.0
# ...                 ...       ...
# 948814              0.0       0.0
# 948815              0.0       0.0
# 948816              0.0       0.0
# 948817             34.0       1.0
# 948818              5.0       0.0
#
# [948819 rows x 15 columns]

# %%
df.columns
# Out:
# Index(['Year', 'Quarter', 'Month', 'DayofMonth', 'FlightDate', 'Origin',
#        'Dest', 'CRSDepTime', 'DepTime', 'DepDelayMinutes', 'DepDel15',
#        'CRSArrTime', 'ArrTime', 'ArrDelayMinutes', 'ArrDel15'],
#       dtype='object')

# %% [markdown]
# ## Doing the above thing for 2017 dataset

# %%
from google.colab import drive
import zipfile
import os
import pandas as pd

zip_path = '/content/drive/MyDrive/Flight Data/2017_original.zip'
extracted_path = '/content/extracted_files'

with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    print(zip_path)
    zip_ref.extractall(extracted_path)
    print(extracted_path)
# Out:
# /content/drive/MyDrive/Flight Data/2017_original.zip
# /content/extracted_files

# %%
import os
import pandas as pd

merged_df = pd.DataFrame()
extracted_path = '/content/extracted_files'

columns_to_keep = ['FlightDate', 'Quarter', 'Year', 'Month', 'DayofMonth', 'DepTime', 'DepDel15',
                   'CRSDepTime', 'DepDelayMinutes', 'Origin', 'Dest', 'ArrTime', 'CRSArrTime',
                   'ArrDel15', 'ArrDelayMinutes']

flight_codes = ['ATL', 'CLT', 'DEN', 'DFW', 'EWR', 'IAH', 'JFK', 'LAS', 'LAX', 'MCO', 'MIA', 'ORD', 'PHX', 'SEA', 'SFO']

for root, dirs, files in os.walk(os.path.join(extracted_path, '2017')):
    for file_name in files:
        if file_name.endswith('.csv'):
            file_path = os.path.join(root, file_name)
            df = pd.read_csv(file_path, usecols=columns_to_keep)

            filtered_df = df[df['Origin'].isin(flight_codes) & df['Dest'].isin(flight_codes)]
            merged_df = pd.concat([merged_df, filtered_df], ignore_index=True)

# Step 4: Save the merged DataFrame to a new CSV file
merged_df.to_csv('/content/merged_file2017_trimmed_final.csv', index=False)
